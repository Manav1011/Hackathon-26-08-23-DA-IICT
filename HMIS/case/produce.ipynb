# %%
import pandas as pd
import numpy as np
import django
import os

# %%
df = pd.read_excel('/home/manav1011/Downloads/New_Sample.xlsx')
df.head(10)
# Out:
#               Medicine Name           Prescription           Type of Sell  \
# 0  Augmentin 625 Duo Tablet  Prescription Required  10 tablets in 1 strip
# 1       Azithral 500 Tablet  Prescription Required   5 tablets in 1 strip
# 2          Ascoril LS Syrup  Prescription Required     100 ml in 1 bottle
# 3      Allegra 120mg Tablet  Prescription Required  10 tablets in 1 strip
# 4            Avil 25 Tablet  Prescription Required  15 tablets in 1 strip
# 5         Aciloc 150 Tablet  Prescription Required  30 tablets in 1 strip
# 6        Atarax 25mg Tablet  Prescription Required  15 tablets in 1 strip
# 7      Amoxyclav 625 Tablet  Prescription Required     strip of 6 tablets
# 8             Anovate Cream  Prescription Required        20 gm in 1 tube
# 9            Avomine Tablet  Prescription Required    strip of 10 tablets
#
#                            Manufacturer  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd
# 1           Alembic Pharmaceuticals Ltd
# ...
